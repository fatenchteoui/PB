# %%
import pandas as pd

import numpy as pn

# %%
df=pd.read_csv("data/data.csv")

# %%
df
# Out:
#        YearWeekISO ReportingCountry  Denominator  NumberDosesReceived  \
# 0         2020-W53               AT    7388778.0                  0.0
# 1         2020-W53               AT    7388778.0                  0.0
# 2         2020-W53               AT    7388778.0                  0.0
# 3         2020-W53               AT    7388778.0                  0.0
# 4         2020-W53               AT    7388778.0                  0.0
# ...            ...              ...          ...                  ...
# 553360    2022-W46               SK     688658.0                  0.0
# 553361    2022-W46               SK     407927.0                  0.0
# 553362    2022-W46               SK     407927.0                  0.0
# 553363    2022-W46               SK     189121.0                  0.0
# 553364    2022-W46               SK     189121.0                  0.0
#
#         NumberDosesExported  FirstDose  FirstDoseRefused  SecondDose  \
# ...

# %%
df.head()
# Out:
#   YearWeekISO ReportingCountry  Denominator  NumberDosesReceived  \
# 0    2020-W53               AT    7388778.0                  0.0
# 1    2020-W53               AT    7388778.0                  0.0
# 2    2020-W53               AT    7388778.0                  0.0
# 3    2020-W53               AT    7388778.0                  0.0
# 4    2020-W53               AT    7388778.0                  0.0
#
#    NumberDosesExported  FirstDose  FirstDoseRefused  SecondDose  \
# 0                  0.0          0               NaN           0
# 1                  0.0          0               NaN           0
# 2                  0.0          0               NaN           0
# 3                  0.0          0               NaN           0
# 4                  0.0          0               NaN           0
#
#    DoseAdditional1  DoseAdditional2  DoseAdditional3  UnknownDose Region  \
# 0                0                0                0            0     AT
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553365 entries, 0 to 553364
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   YearWeekISO          553365 non-null  object
#  1   ReportingCountry     553365 non-null  object
#  2   Denominator          292228 non-null  float64
#  3   NumberDosesReceived  68066 non-null   float64
#  4   NumberDosesExported  72101 non-null   float64
#  5   FirstDose            553365 non-null  int64
#  6   FirstDoseRefused     1447 non-null    float64
#  7   SecondDose           553365 non-null  int64
#  8   DoseAdditional1      553365 non-null  int64
#  9   DoseAdditional2      553365 non-null  int64
#  10  DoseAdditional3      553365 non-null  int64
#  11  UnknownDose          553365 non-null  int64
#  12  Region               553365 non-null  object
#  13  TargetGroup          553365 non-null  object
#  14  Vaccine              553365 non-null  object
# ...

# %%
print(df.head().to_markdown())
# Out:
# |    | YearWeekISO   | ReportingCountry   |   Denominator |   NumberDosesReceived |   NumberDosesExported |   FirstDose |   FirstDoseRefused |   SecondDose |   DoseAdditional1 |   DoseAdditional2 |   DoseAdditional3 |   UnknownDose | Region   | TargetGroup   | Vaccine   |   Population |
# |---:|:--------------|:-------------------|--------------:|----------------------:|----------------------:|------------:|-------------------:|-------------:|------------------:|------------------:|------------------:|--------------:|:---------|:--------------|:----------|-------------:|
# |  0 | 2020-W53      | AT                 |   7.38878e+06 |                     0 |                     0 |           0 |                nan |            0 |                 0 |                 0 |                 0 |             0 | AT       | ALL           | AZ        |      8901064 |
# ...
